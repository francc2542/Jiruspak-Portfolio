# %% [markdown]
# **Attribute Information**
# - **nvoice_no :** Invoice number. Nominal. A combination of the letter 'I' and a 6-digit integer uniquely assigned to each operation.
# - **customer_id :**  Customer number. Nominal. A combination of the letter 'C' and a 6-digit integer uniquely assigned to each operation.
# - **gender :** String variable of the customer's gender.
# - **age :** Positive Integer variable of the customers age.
# - **category :** String variable of the category of the purchased product.
# - **quantity :** The quantities of each product (item) per transaction. Numeric.
# - **price :** Unit price. Numeric. Product price per unit in Turkish Liras (TL).
# - **payment_method :** String variable of the payment method (cash, credit card or debit card) used for the transaction.
# - **invoice_date :** Invoice date. The day when a transaction was generated.
# - **shopping_mall :** String variable of the name of the shopping mall where the transaction was made.

# %%
# Import libraries and the .csv file.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('customer_shopping_data.csv', encoding = 'utf-8')
df
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
# Shape of dataframe.
df.shape
# Out:
# (99457, 10)

# %%
# Preview top 5 rows.
df.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card     5/8/2022          Kanyon
# 1     Debit Card   12/12/2021  Forum Istanbul
# 2           Cash    9/11/2021       Metrocity
# 3    Credit Card   16/05/2021    Metropol AVM
# 4           Cash   24/10/2021          Kanyon

# %%
# Preview bottom 5 rows.
df.tail()
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 99452    Credit Card   21/09/2022            Kanyon
# 99453           Cash   22/09/2021    Forum Istanbul
# 99454     Debit Card   28/03/2021         Metrocity
# 99455           Cash   16/03/2021      Istinye Park
# 99456    Credit Card   15/10/2022  Mall of Istanbul

# %%
# See data frame information using .info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      99457 non-null  object
#  1   customer_id     99457 non-null  object
#  2   gender          99457 non-null  object
#  3   age             99457 non-null  int64
#  4   category        99457 non-null  object
#  5   quantity        99457 non-null  int64
#  6   price           99457 non-null  float64
#  7   payment_method  99457 non-null  object
#  8   invoice_date    99457 non-null  object
#  9   shopping_mall   99457 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 7.6+ MB

# %%
# Convert the data type of the 'invoice_date' object to datetime in the original dataframe.
df['invoice_date'] = pd.to_datetime(df['invoice_date'], format='%d/%m/%Y')
df.sample(5)
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 45788    I954697     C299232  Female   43             Toys         1    35.84
# 9190     I329011     C776956  Female   22  Food & Beverage         5    26.15
# 21603    I151704     C217858  Female   45        Cosmetics         3   121.98
# 14588    I143452     C238871  Female   56            Shoes         3  1800.51
# 91665    I699716     C143474  Female   51         Clothing         3   900.24
#
#       payment_method invoice_date     shopping_mall
# 45788    Credit Card   2022-05-02    Viaport Outlet
# 9190     Credit Card   2022-04-07         Metrocity
# 21603    Credit Card   2022-03-25  Mall of Istanbul
# 14588           Cash   2022-08-28    Viaport Outlet
# 91665           Cash   2021-02-27  Mall of Istanbul

# %%
# Calculate the total price.
df['Total_price'] = df['quantity'] * df['price']
df.sample(5)
# Out:
#       invoice_no customer_id  gender  age    category  quantity    price  \
# 26275    I244334     C154224  Female   21       Shoes         3  1800.51
# 11830    I336335     C256800    Male   56       Books         2    30.30
# 95392    I246399     C237790  Female   45   Cosmetics         2    81.32
# 37503    I261561     C705697  Female   26   Cosmetics         1    40.66
# 22277    I262593     C222472  Female   29  Technology         4  4200.00
#
#       payment_method invoice_date      shopping_mall  Total_price
# 26275     Debit Card   2022-09-14   Mall of Istanbul      5401.53
# 11830    Credit Card   2023-02-20   Mall of Istanbul        60.60
# 95392     Debit Card   2022-02-10  Emaar Square Mall       162.64
# 37503           Cash   2022-03-14   Mall of Istanbul        40.66
# 22277           Cash   2021-09-09  Emaar Square Mall     16800.00

# %%
# Additionally, we create new columns for the year and month, which can be useful for further analysis.
df['invoice_month'] = df['invoice_date'].dt.month
df['invoice_year'] = df['invoice_date'].dt.year
df.sample(5)
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 3225     I328623     C327607  Female   60         Clothing         4  1200.32
# 26884    I304874     C498331  Female   37            Books         1    15.15
# 44444    I248657     C217405    Male   66         Clothing         4  1200.32
# 38110    I102232     C282538  Female   40             Toys         2    71.68
# 88696    I182463     C157294    Male   60  Food & Beverage         3    15.69
#
#       payment_method invoice_date     shopping_mall  Total_price  \
# 3225      Debit Card   2021-12-12            Kanyon      4801.28
# 26884     Debit Card   2022-11-29         Metrocity        15.15
# 44444    Credit Card   2023-01-04      Istinye Park      4801.28
# 38110    Credit Card   2022-12-03  Mall of Istanbul       143.36
# 88696     Debit Card   2023-02-18  Mall of Istanbul        47.07
#
#        invoice_month  invoice_year
# 3225              12          2021
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      99457 non-null  object
#  1   customer_id     99457 non-null  object
#  2   gender          99457 non-null  object
#  3   age             99457 non-null  int64
#  4   category        99457 non-null  object
#  5   quantity        99457 non-null  int64
#  6   price           99457 non-null  float64
#  7   payment_method  99457 non-null  object
#  8   invoice_date    99457 non-null  datetime64[ns]
#  9   shopping_mall   99457 non-null  object
#  10  Total_price     99457 non-null  float64
#  11  invoice_month   99457 non-null  int32
#  12  invoice_year    99457 non-null  int32
# dtypes: datetime64[ns](1), float64(2), int32(2), int64(2), object(6)
# memory usage: 9.1+ MB

# %%
# Check missing values in each column
df.isnull().sum()
# Out:
# invoice_no        0
# customer_id       0
# gender            0
# age               0
# category          0
# quantity          0
# price             0
# payment_method    0
# invoice_date      0
# shopping_mall     0
# Total_price       0
# invoice_month     0
# invoice_year      0
# dtype: int64

# %%
# Summary stats.
df[['Total_price', 'quantity', 'price', 'Total_price']].describe()
# Out:
#         Total_price      quantity         price   Total_price
# count  99457.000000  99457.000000  99457.000000  99457.000000
# mean    2528.789268      3.003429    689.256321   2528.789268
# std     4222.475781      1.413025    941.184567   4222.475781
# min        5.230000      1.000000      5.230000      5.230000
# 25%      136.350000      2.000000     45.450000    136.350000
# 50%      600.170000      3.000000    203.300000    600.170000
# 75%     2700.720000      4.000000   1200.320000   2700.720000
# max    26250.000000      5.000000   5250.000000  26250.000000

# %%
# Create a line graph to observe the monthly income trends.
year_month = df.groupby(['invoice_year', 'invoice_month'])['Total_price'].sum()
plt.figure(figsize=(10, 8))
year_month.plot(marker = "o")
plt.title('The trend of monthly sales', size = 20)
plt.xlabel('Year, Month', size = 10)
plt.ylabel('Total Sales', size = 10)
plt.grid(True)
plt.show()

# %%
# Prepare data to create a pie chart depicting income for each year.
year_price = df.groupby('invoice_year')['Total_price'].sum().reset_index()
year_price
# Out:
#    invoice_year   Total_price
# 0          2021  1.145606e+08
# 1          2022  1.154368e+08
# 2          2023  2.150841e+07

# %%
# Create a pie chart illustrating income for each year.
exp = [0, 0, 0.1]

plt.pie(year_price['Total_price'], labels = year_price['invoice_year'], autopct = "%.2f%%", shadow = True, explode = exp)
plt.title('Annual income.', size = 15)
plt.show()

# %%
# Explore age distribution.
ages = df['age'].value_counts().reset_index()
ages.sort_values('age')
# Out:
#     age  count
# 47   18   1844
# 17   19   1936
# 48   20   1844
# 14   21   1947
# 1    22   2051
# 26   23   1897
# 6    24   1977
# 45   25   1863
# 27   26   1896
# 12   27   1950
# 11   28   1953
# 33   29   1885
# 5    30   1981
# 44   31   1866
# 31   32   1891
# 19   33   1913
# 35   34   1883
# 50   35   1841
# 9    36   1954
# 0    37   2057
# 10   38   1954
# 13   39   1947
# 7    40   1960
# 30   41   1892
# 29   42   1892
# 3    43   2000
# 22   44   1904
# 39   45   1876
# 20   46   1911
# 36   47   1880
# 8    48   1955
# 34   49   1883
# 43   50   1873
# 4    51   1993
# 16   52   1945
# 23   53   1903
# 51   54   1830
# 49   55   1843
# 18   56   1916
# 37   57   1879
# 40   58   1875
# 41   59   1874
# 42   60   1874
# 15   61   1945
# 21   62   1909
# 32   63   1886
# 2    64   2002
# 46   65   1856
# 38   66   1876
# 24   67   1901
# 28   68   1893
# 25   69   1901

# %%
# Create a histogram graph showing the age groups of customers who made purchases.
plt.hist(df['age'], bins = 20)
plt.xlabel("Age", size = 10)
plt.ylabel("Count", size = 10)
plt.title("Frequency Distribution of Age", size = 20)
plt.grid(True)
plt.show()

# %%
# Prepare data to create a bar chart illustrating the number of purchases in each product category, segmented by gender.
category = df.groupby(['category','gender'])['quantity'].sum().reset_index()
category
# Out:
#            category  gender  quantity
# 0             Books  Female      8776
# 1             Books    Male      6206
# 2          Clothing  Female     62039
# 3          Clothing    Male     41519
# 4         Cosmetics  Female     27261
# 5         Cosmetics    Male     18204
# 6   Food & Beverage  Female     26362
# 7   Food & Beverage    Male     17915
# 8             Shoes  Female     17906
# 9             Shoes    Male     12311
# 10         Souvenir  Female      8976
# 11         Souvenir    Male      5895
# 12       Technology  Female      8977
# 13       Technology    Male      6044
# 14             Toys  Female     18362
# 15             Toys    Male     11959

# %%
# Create a bar chart showing the number of purchases in each product category, segmented by gender.
sns.barplot(data=category, x = 'category', y = 'quantity', hue='gender')
plt.xlabel('Categories', size = 10)
plt.ylabel('Qntity', size = 10)
plt.title('The number of orders in each product category.', size = 15)
plt.grid(True)
plt.xticks(rotation=50)
plt.show()

# %%
# Prepare the data to create a bar chart showing the income in each product category, segmented by gender.
Total_price_category = df.groupby(['category','gender'])['Total_price'].sum().reset_index()
Total_price_category
# Out:
#            category  gender  Total_price
# 0             Books  Female    489314.70
# 1             Books    Male    345238.20
# 2          Clothing  Female  68251695.60
# 3          Clothing    Male  45745095.44
# 4         Cosmetics  Female   4066772.54
# 5         Cosmetics    Male   2726090.36
# 6   Food & Beverage  Female    505322.60
# 7   Food & Beverage    Male    344212.45
# 8             Shoes  Female  39425167.30
# 9             Shoes    Male  27128284.17
# 10         Souvenir  Female    382867.20
# 11         Souvenir    Male    252957.45
# 12       Technology  Female  34669950.00
# 13       Technology    Male  23192400.00
# 14             Toys  Female   2416046.08
# 15             Toys    Male   1564380.16

# %%
# Create a bar chart showing the income in each product category, segmented by gender.
sns.barplot(data=Total_price_category, x = 'category', y = 'Total_price', hue = 'gender')
plt.xlabel('Categories', size = 10)
plt.ylabel('Total Sales', size = 10)
plt.title('The total revenue for each product category.', size = 15)
plt.grid(True)
plt.xticks(rotation=50)
plt.show()

# %%
# Prepare data to create a bar chart illustrating the income in each shopping mall.
shopping_mall_price = df.groupby('shopping_mall')['Total_price'].sum().reset_index()
shopping_mall_price
# Out:
#        shopping_mall  Total_price
# 0        Cevahir AVM  12645138.20
# 1  Emaar Square Mall  12406100.29
# 2     Forum Istanbul  12303921.24
# 3       Istinye Park  24618827.68
# 4             Kanyon  50554231.10
# 5   Mall of Istanbul  50872481.68
# 6          Metrocity  37302787.33
# 7       Metropol AVM  25379913.19
# 8     Viaport Outlet  12521339.72
# 9       Zorlu Center  12901053.82

# %%
# Create a bar chart to see which shopping mall has the highest income.
plt.barh(shopping_mall_price['shopping_mall'], shopping_mall_price['Total_price'])
plt.xlabel("Mall", size = 10)
plt.ylabel("Total Sales", size = 10)
plt.title("The total revenue for each shopping mall.", size = 20)
plt.show()

# %%
# Prepare the data to create a bar chart showing the number of customers who use the services in each shopping mall, segmented by gender.
shopping_mall_counts = df.groupby(['shopping_mall','gender'])['gender'].value_counts().reset_index()
shopping_mall_counts
# Out:
#         shopping_mall  gender  count
# 0         Cevahir AVM  Female   2940
# 1         Cevahir AVM    Male   2051
# 2   Emaar Square Mall  Female   2842
# 3   Emaar Square Mall    Male   1969
# 4      Forum Istanbul  Female   3016
# 5      Forum Istanbul    Male   1931
# 6        Istinye Park  Female   5874
# 7        Istinye Park    Male   3907
# 8              Kanyon  Female  11906
# 9              Kanyon    Male   7917
# 10   Mall of Istanbul  Female  11902
# 11   Mall of Istanbul    Male   8041
# 12          Metrocity  Female   8941
# 13          Metrocity    Male   6070
# 14       Metropol AVM  Female   6144
# 15       Metropol AVM    Male   4017
# 16     Viaport Outlet  Female   2949
# 17     Viaport Outlet    Male   1965
# 18       Zorlu Center  Female   2968
# 19       Zorlu Center    Male   2107

# %%
# Create a bar chart to see which shopping mall has the highest number of customers using services, segmented by gender.
sns.barplot(data=shopping_mall_counts, x = 'shopping_mall', y = 'count', hue = 'gender')
plt.xlabel('Mall', size = 10)
plt.ylabel('Count', size = 10)
plt.title('The number of people who visited each shopping mall.', size = 15)
plt.grid(True)
plt.xticks(rotation=50)
plt.show()

# %%
# Prepare the data to create a pie chart showing popular payment methods.
payment = df.groupby('payment_method')['payment_method'].value_counts().reset_index()
payment
# Out:
#   payment_method  count
# 0           Cash  44447
# 1    Credit Card  34931
# 2     Debit Card  20079

# %%
# Create a pie chart to visualize popular payment methods.
exp = [0, 0, 0.1]

plt.pie(payment['count'], labels = payment['payment_method'], autopct = "%.2f%%", shadow = True, explode = exp)
plt.title('Popular payment methods.', size = 15)
plt.show()
